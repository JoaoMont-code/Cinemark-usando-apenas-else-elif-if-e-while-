# %%
x = 0

ValorFilme1=20.00
ValorFilme2=15.00
ValorFilme3=10.00

assento1 = 50
assento2 = 40
assento2 = 30

ValorInteira1=0
QtdeInteira1=0

ValorMeia1=0
QtdeMeia1=0

ValorVip1=0
QtdeVip1=0


while x != 1:
    
    print('-------------------MENU---------------------')
    print('-----------------CineMark--------------------')
    print('1. Comprar ingressos para Filme 1 - Sessão 1')
    print('2. Comprar ingressos para Filme 1 - Sessão 2')
    print('3. Comprar ingressos para Filme 2 - Sessão 1')
    print('4. Comprar ingressos para Filme 2 - Sessão 2')
    print('5. Comprar ingressos para Filme 3 - Sessão 1')
    print('6. Comprar ingressos para Filme 3 - Sessão 2')
    print('7. Avaliar um filme')
    print('8. Encerrar o dia e exibir o relatório')
    
    opcao = input("\n\n\nEscolha uma opção: ")
        
    if opcao == "1":
    
            
            print ('\nAssentos disponíveis para Filme 1 - Sessão 1 :' + str(assento1) + ' Assentos')
                            
            ingresso1 = input('\nEscolha Seu Assento:')  
                        
            print ('\nEscolha o tipo de ingresso (1: Inteira, 2: Meia, 3: VIP, 4: Voltar')
            ingresso1 = input('\nEscolha o tipo de ingresso:')
            
            if ingresso1 == "1":
                assento1 = assento1 - 1
                ValorInteira1=ValorInteira1 + ValorFilme1
                QtdeInteira1 = QtdeInteira1 + 1
                continue
                
            elif ingresso1 == "2":
                assento1 = assento1 - 1
                ValorMeia1 = ValorMeia1 + ValorFilme1/2
                QtdeMeia1=QtdeMeia1+1
                continue
                
            elif ingresso1 == "3":
                assento1 = assento1 - 1
                ValorVip1 = ValorVip1 + (ValorFilme1 * 1.5)
                QtdeVip1=QtdeVip1 + 1
                continue
                
            elif ingresso1 == "4":
                continue




    if opcao == "2":

            print ('\nAssentos disponíveis para Filme 1 - Sessão 2 :' + str(assento1) + ' Assentos')
                            
            ingresso2 = input('\nEscolha Seu Assento:')  
                        
            print ('\nEscolha o tipo de ingresso (1: Inteira, 2: Meia, 3: VIP, 4: Voltar')
            ingresso1 = input('\nEscolha o tipo de ingresso:')
            
            if ingresso2 == "1":
                assento1 = assento1 - 1
                ValorInteira1=ValorInteira1 + ValorFilme1
                QtdeInteira1 = QtdeInteira1 + 1
                continue
                
            elif ingresso2 == "2":
                assento1 = assento1 - 1
                ValorMeia1 = ValorMeia1 + ValorFilme1/2
                QtdeMeia1=QtdeMeia1+1
                continue
                
            elif ingresso2 == "3":
                assento1 = assento1 - 1
                ValorVip1 = ValorVip1 + (ValorFilme1 * 1.5)
                QtdeVip1=QtdeVip1 + 1
                continue
                
            elif ingresso1 == "4":
                continue


    if opcao == "3":

            print ('\nAssentos disponíveis para Filme 2 - Sessão 1 :' + str(assento1) + ' Assentos')
                            
            ingresso3 = input('\nEscolha Seu Assento:')  
                        
            print ('\nEscolha o tipo de ingresso (1: Inteira, 2: Meia, 3: VIP, 4: Voltar')
            ingresso1 = input('\nEscolha o tipo de ingresso:')
            
            if ingresso3 == "1":
                assento1 = assento1 - 1
                ValorInteira1=ValorInteira1 + ValorFilme1
                QtdeInteira1 = QtdeInteira1 + 1
                continue
                
            elif ingresso3 == "2":
                assento1 = assento1 - 1
                ValorMeia1 = ValorMeia1 + ValorFilme1/2
                QtdeMeia1=QtdeMeia1+1
                continue
                
            elif ingresso3 == "3":
                assento1 = assento1 - 1
                ValorVip1 = ValorVip1 + (ValorFilme1 * 1.5)
                QtdeVip1=QtdeVip1 + 1
                continue
                
            elif ingresso1 == "4":
                continue


    if opcao == "4":
           

            print ('\nAssentos disponíveis para Filme 2 - Sessão 2 :' + str(assento1) + ' Assentos')
                            
            ingresso4 = input('\nEscolha Seu Assento:')  
                        
            print ('\nEscolha o tipo de ingresso (1: Inteira, 2: Meia, 3: VIP, 4: Voltar')
            ingresso1 = input('\nEscolha o tipo de ingresso:')
            
            if ingresso4 == "1":
                assento1 = assento1 - 1
                ValorInteira1=ValorInteira1 + ValorFilme1
                QtdeInteira1 = QtdeInteira1 + 1
                continue
                
            if ingresso4 == "2":
                assento1 = assento1 - 1
                ValorMeia1 = ValorMeia1 + ValorFilme1/2
                QtdeMeia1=QtdeMeia1+1
                continue
                
            if ingresso4 == "3":
                assento1 = assento1 - 1
                ValorVip1 = ValorVip1 + (ValorFilme1 * 1.5)
                QtdeVip1=QtdeVip1 + 1
                continue
                
            if ingresso1 == "4":
                continue



    if opcao == "5":

            print ('\nAssentos disponíveis para Filme 3 - Sessão 1 :' + str(assento1) + ' Assentos')
                            
            ingresso5 = input('\nEscolha Seu Assento:')  
                        
            print ('\nEscolha o tipo de ingresso (1: Inteira, 2: Meia, 3: VIP, 4: Voltar')
            ingresso1 = input('\nEscolha o tipo de ingresso:')
            
            if ingresso5 == "1":
                assento1 = assento1 - 1
                ValorInteira1=ValorInteira1 + ValorFilme1
                QtdeInteira1 = QtdeInteira1 + 1
                continue
                
            elif ingresso5 == "2":
                assento1 = assento1 - 1
                ValorMeia1 = ValorMeia1 + ValorFilme1/2
                QtdeMeia1=QtdeMeia1+1
                continue
                
            elif ingresso5 == "3":
                assento1 = assento1 - 1
                ValorVip1 = ValorVip1 + (ValorFilme1 * 1.5)
                QtdeVip1=QtdeVip1 + 1
                continue
                
            elif ingresso1 == "4":
                continue


    if opcao == "6":

            print ('\nAssentos disponíveis para Filme 3 - Sessão 2 :' + str(assento1) + ' Assentos')
                            
            ingresso6 = input('\nEscolha Seu Assento:')  
                        
            print ('\nEscolha o tipo de ingresso (1: Inteira, 2: Meia, 3: VIP, 4: Voltar')
            ingresso1 = input('\nEscolha o tipo de ingresso:')
            
            if ingresso6 == "1":
                assento1 = assento1 - 1
                ValorInteira1=ValorInteira1 + ValorFilme1
                QtdeInteira1 = QtdeInteira1 + 1
                continue
                
            elif ingresso6 == "2":
                assento1 = assento1 - 1
                ValorMeia1 = ValorMeia1 + ValorFilme1/2
                QtdeMeia1=QtdeMeia1+1
                continue
                
            elif ingresso6 == "3":
                assento1 = assento1 - 1
                ValorVip1 = ValorVip1 + (ValorFilme1 * 1.5)
                QtdeVip1=QtdeVip1 + 1
                continue
                
            elif ingresso1 == "4":
                continue

    if opcao == "7":
            print("Escolha um filme para avaliar:")
            print("1. Avaliar Filme 1,Sessão 1: ")
            print("2. Avaliar Filme 1,Sessão 2: ")
            print("3. Avaliar Filme 2,Sessão 1: ")
            print("4. Avaliar Filme 2,Sessão 2: ")
            print("5. Avaliar Filme 3,Sessão 1: ")
            print("6. Avaliar Filme 3,Sessão 2: ")
        
            filme_avaliar = int(input("Escolha um filme: ")) 
            an = input("\nAvalie o filme (1 a 5 estrelas): ")
            continue 

    elif opcao == "2":
        x = 1
    elif opcao == "4":
        x = 1
    elif opcao == "5":
        x = 1
    elif opcao == "6":
        x = 1            
    elif opcao == "7":
        x = 1            
    if  opcao == "8":
            print("1. Relatorio final Filme 1,Sessão 1: ")
            print("2. Relatorio final Filme 1,Sessão 2: ")
            print("3. Relatorio final 2,Sessão 1: ")
            print("4. Relatorio final 2,Sessão 2: ")
            print("5. Relatorio final 3,Sessão 1: ")
            print("6. Relatorio final 3,Sessão 2: ")
        
    a = input("\nEscolha um filme para fazer o relatorio: ")
    if a == '1':
                print('---------------Relatório Final----------------')
                print('------------Filme 1 - Sessão 1 ---------------')
                print('-------Quantidade de ingressos vendidos-------')
                print('\nInteira -> ' + str(QtdeInteira1))
                print('Meia      -> ' + str(QtdeMeia1))
                print('VIP       -> ' + str(QtdeVip1))
                print('Total de ingressos vendidos no filme 1 (Sessão 1): ', QtdeInteira1  + QtdeMeia1  + QtdeVip1)
                print('\nReceita por tipo  (Sessão 1): ')
                print('Inteira -> R$ ' + str(ValorInteira1))
                print('Meia    -> R$ ' + str(ValorMeia1))
                print('VIP     -> R$ ' + str(ValorVip1) ) 
                print('Total de ingressos vendidos no filme 1 (Sessão 1): ', ValorInteira1  + ValorMeia1  + ValorVip1)
                print('\n Media Avaliação (Sessão 1) : ')
                print(' Media Avaliação ->  ' +  (an))
                x = 1
                        
    elif a == "2":
                print('---------------Relatório Final----------------')
                print('------------Filme 1 - Sessão 2 ---------------')
                print('-------Quantidade de ingressos vendidos-------')
                print('\nInteira -> ' + str(QtdeInteira1))
                print('Meia      -> ' + str(QtdeMeia1))
                print('VIP       -> ' + str(QtdeVip1))
                print('Total de ingressos vendidos no filme 1 (Sessão 2): ', QtdeInteira1  + QtdeMeia1  + QtdeVip1)
                print('\nReceita por tipo  (Sessão 2): ')
                print('Inteira -> R$ ' + str(ValorInteira1))
                print('Meia    -> R$ ' + str(ValorMeia1))
                print('VIP     -> R$ ' + str(ValorVip1) ) 
                print('Total de ingressos vendidos no filme 1 (Sessão 2): ', ValorInteira1  + ValorMeia1  + ValorVip1)
                print('\n Media Avaliação (Sessão 2) : ')
                print(' Media Avaliação ->  ' +  (an))
                x = 1
                
    elif a == "3":
                print('---------------Relatório Final----------------')
                print('------------Filme 2 - Sessão 1 ---------------')
                print('-------Quantidade de ingressos vendidos-------')
                print('\nInteira -> ' + str(QtdeInteira1))
                print('Meia      -> ' + str(QtdeMeia1))
                print('VIP       -> ' + str(QtdeVip1))
                print('Total de ingressos vendidos no filme 2 (Sessão 1): ', QtdeInteira1  + QtdeMeia1  + QtdeVip1)
                print('\nReceita por tipo  (Sessão 1): ')
                print('Inteira -> R$ ' + str(ValorInteira1))
                print('Meia    -> R$ ' + str(ValorMeia1))
                print('VIP     -> R$ ' + str(ValorVip1) )  
                print('Total de ingressos vendidos no filme 2 (Sessão 1): ', ValorInteira1  + ValorMeia1  + ValorVip1)
                print('\n Media Avaliação (Sessão 1) : ')
                print(' Media Avaliação ->  ' +  (an))
                x = 1
                
    elif a == "4":
                print('---------------Relatório Final----------------')
                print('------------Filme 2 - Sessão 2 ---------------')
                print('-------Quantidade de ingressos vendidos-------')
                print('\nInteira -> ' + str(QtdeInteira1))
                print('Meia      -> ' + str(QtdeMeia1))
                print('VIP       -> ' + str(QtdeVip1))
                print('Total de ingressos vendidos no filme 2 (Sessão 2): ', QtdeInteira1  + QtdeMeia1  + QtdeVip1)
                print('\nReceita por tipo  (Sessão 2): ')
                print('Inteira -> R$ ' + str(ValorInteira1))
                print('Meia    -> R$ ' + str(ValorMeia1))
                print('VIP     -> R$ ' + str(ValorVip1) )  
                print('Total de ingressos vendidos no filme 3 (Sessão 2): ', ValorInteira1  + ValorMeia1  + ValorVip1)
                print('\n Media Avaliação (Sessão 2) : ')
                print(' Media Avaliação ->  ' +  (an))
                x = 1

    elif a == "5":
                print('---------------Relatório Final----------------')
                print('------------Filme 3 - Sessão 1 ---------------')
                print('-------Quantidade de ingressos vendidos-------')
                print('\nInteira -> ' + str(QtdeInteira1))
                print('Meia      -> ' + str(QtdeMeia1))
                print('VIP       -> ' + str(QtdeVip1))
                print('Total de ingressos vendidos no filme 3 (Sessão 1): ', QtdeInteira1  + QtdeMeia1  + QtdeVip1)
                print('\nReceita por tipo  (Sessão 1): ')
                print('Inteira -> R$ ' + str(ValorInteira1))
                print('Meia    -> R$ ' + str(ValorMeia1))
                print('VIP     -> R$ ' + str(ValorVip1) ) 
                print('Total de ingressos vendidos no filme 3 (Sessão 2): ', ValorInteira1  + ValorMeia1  + ValorVip1)
                print('\n Media Avaliação (Sessão 1) : ')
                print(' Media Avaliação ->  ' +  (an))
                x = 1
            

    elif a == "6":
                print('---------------Relatório Final----------------')
                print('------------Filme 3 - Sessão 2 ---------------')
                print('-------Quantidade de ingressos vendidos-------')
                print('\nInteira -> ' + str(QtdeInteira1))
                print('Meia      -> ' + str(QtdeMeia1))
                print('VIP       -> ' + str(QtdeVip1))
                print('Total de ingressos vendidos no filme 3 (Sessão 2): ', QtdeInteira1  + QtdeMeia1  + QtdeVip1)
                print('\nReceita por tipo  (Sessão 2): ')
                print('Inteira -> R$ ' + str(ValorInteira1))
                print('Meia    -> R$ ' + str(ValorMeia1))
                print('VIP     -> R$ ' + str(ValorVip1) )  
                print('Total de ingressos vendidos no filme 3 (Sessão 2): ', ValorInteira1  + ValorMeia1  + ValorVip1)
                print('\n Media Avaliação (Sessão 2) : ')
                print(' Media Avaliação ->  ' +  (an))
                x = 1
                
    else:
        print('Opção invalida')
# Out:
# -------------------MENU---------------------
# -----------------CineMark--------------------
# 1. Comprar ingressos para Filme 1 - Sessão 1
# 2. Comprar ingressos para Filme 1 - Sessão 2
# 3. Comprar ingressos para Filme 2 - Sessão 1
# 4. Comprar ingressos para Filme 2 - Sessão 2
# 5. Comprar ingressos para Filme 3 - Sessão 1
# 6. Comprar ingressos para Filme 3 - Sessão 2
# 7. Avaliar um filme
# 8. Encerrar o dia e exibir o relatório
